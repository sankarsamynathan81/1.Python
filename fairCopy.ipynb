# %%
#From Filename import classname
from multipleFunctions import multipleFunctionsTest

# %%
multipleFunctionsTest.OddEven()
# Out:
# Enter a number 23
# 23 is Odd number
# 'Odd number'

# %%
multipleFunctionsTest.bmiCalculation()
# Out:
# Enter the BMI Index 23
# Normal, keep it up!
# 'Normal, keep it up!'

# %%
multipleFunctionsTest.percentage()
# Out:
# Total= 468
# Average= 93.6
# 93.6

# %%
multipleFunctionsTest.triangle()
# Out:
# Area formula : (Height*Breath)/2
# Area of Triangle : 544.0
# Height1 : 2
# Height2 : 4
# Breath : 4
# Perimeter formula = Height1+Height2+Breath
# Perimeter of Triangle =  10
