# %%
num1=int(input("Enter number1"))
# Out:
# Enter number1 50

# %%
print(num1)
# Out:
# 50

# %%
num2=int(input("Enter number2"))
# Out:
# Enter number2 30

# %%
add=num1+num2
print("add=",add)
# Out:
# add= 80
