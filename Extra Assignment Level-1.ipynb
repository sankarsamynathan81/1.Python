# %%
#PRINT STATEMENT
name="Hope AI"
print(name)
# Out:
# Hope AI

# %%
#Buy Input
nameData=input("Enter your Institude name")
print("Enter your Institude name?:",nameData)
# Out:
# Enter your Institude name regrejk
# Enter your Institude name?: regrejk

# %%
#Buy Inputs
name=input("Enter your name=")
age=input("Enter your age=")
schoolName=input("Enter your Schoolname=")
degree=input("Enter your degreee=")
# Out:
# Enter your name= Sankar
# Enter your age= 2
# Enter your Schoolname= ATM
# Enter your degreee= Appliled science

# %%
#Addition
a=43
b=34
add=a+b
print("a=",a)
print("b=",b)
print("add=",add)
# Out:
# a= 43
# b= 34
# add= 77

# %%
#Multiplication
a=63
b=97
print("a=",a)
print("b=",b)
mul=a*b
print("Mul=",mul)
# Out:
# a= 63
# b= 97
# Mul= 6111

# %%
#Division
a=76
b=31
print("a=",a)
print("b=",b)
print("Float Div=",a/b)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
#Floor Division 
a=76
b=31
print("a=",a)
print("b=",b)
print("Floor Div=",a//b)
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
#Modulo
a=76
b=31
print("a=",a)
print("b=",b)
print("Modulo=",a%b)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
#Power
a= 4
b= 4
print("a=",a)
print("b=",b)
print("Power =",pow(4,4))
# Out:
# a= 4
# b= 4
# Power = 256
